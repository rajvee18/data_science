# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('/home/code_wizard/coding_files/data_science/datasets/Unsupervised Machine Learning with K-Means Clustering in Python/Mall_Customers.csv')

x = df.iloc[:,3:5].values
x
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %% [markdown]
# ### Using Elbow method to find optimal number of clusters

# %%
wcss = []

for i in range(1,11):
    kmeans = KMeans(n_clusters=i,init='k-means++',random_state=1)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,11),wcss)

plt.title("The Elbow Curve")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
# Out:
# Text(0, 0.5, 'WCSS')

# %% [markdown]
# ### Training the dataset on KMeans with clusters=5

# %%
kmeans1 = KMeans(n_clusters=5,init='k-means++',random_state=1)

y_kmeans = kmeans1.fit_predict(x)


print(np.concatenate((x,y_kmeans.reshape(len(y_kmeans),1)),1))
# Out:
# [[ 15  39   4]
#  [ 15  81   2]
#  [ 16   6   4]
#  [ 16  77   2]
#  [ 17  40   4]
#  [ 17  76   2]
#  [ 18   6   4]
#  [ 18  94   2]
#  [ 19   3   4]
#  [ 19  72   2]
#  [ 19  14   4]
#  [ 19  99   2]
#  [ 20  15   4]
#  [ 20  77   2]
#  [ 20  13   4]
#  [ 20  79   2]
#  [ 21  35   4]
#  [ 21  66   2]
#  [ 23  29   4]
#  [ 23  98   2]
#  [ 24  35   4]
#  [ 24  73   2]
#  [ 25   5   4]
#  [ 25  73   2]
#  [ 28  14   4]
#  [ 28  82   2]
#  [ 28  32   4]
#  [ 28  61   2]
#  [ 29  31   4]
#  [ 29  87   2]
#  [ 30   4   4]
#  [ 30  73   2]
#  [ 33   4   4]
#  [ 33  92   2]
#  [ 33  14   4]
#  [ 33  81   2]
#  [ 34  17   4]
#  [ 34  73   2]
#  [ 37  26   4]
#  [ 37  75   2]
#  [ 38  35   4]
#  [ 38  92   2]
#  [ 39  36   4]
#  [ 39  61   0]
#  [ 39  28   4]
#  [ 39  65   2]
#  [ 40  55   0]
#  [ 40  47   0]
#  [ 40  42   0]
#  [ 40  42   0]
#  [ 42  52   0]
#  [ 42  60   0]
#  [ 43  54   0]
#  [ 43  60   0]
#  [ 43  45   0]
#  [ 43  41   0]
#  [ 44  50   0]
#  [ 44  46   0]
# ...

# %%
x[y_kmeans==0,1].shape
# Out:
# (81,)

# %%
plt.scatter(x[y_kmeans==0,0],x[y_kmeans==0,1],color = 'red',label = 'cluster 1')
plt.scatter(x[y_kmeans==1,0],x[y_kmeans==1,1],color = 'blue',label = 'cluster 2')
plt.scatter(x[y_kmeans==2,0],x[y_kmeans==2,1],color = 'black',label = 'cluster 3')
plt.scatter(x[y_kmeans==3,0],x[y_kmeans==3,1],color = 'green',label = 'cluster 4')
plt.scatter(x[y_kmeans==4,0],x[y_kmeans==4,1],color = 'cyan',label = 'cluster 5')

centroids = kmeans1.cluster_centers_

plt.scatter(centroids[:,0],centroids[:,1],s = 300, color = 'yellow',label = 'centriods')

plt.legend()
plt.xlabel("annual income")
plt.ylabel("spending score")
# Out:
# Text(0, 0.5, 'spending score')
